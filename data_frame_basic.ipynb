# %% [markdown]
# ### Data frame
# >A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
import pandas as pd

# %%
data={
    "Cars":["Audi","Bmw","Bughati"],
    "speed":[140,135,400],
    "price":[100000,30000,150032]
}
df=pd.DataFrame(data)
df
df.loc[0:1]
# Out:
#    Cars  speed   price
# 0  Audi    140  100000
# 1   Bmw    135   30000

# %%
data=pd.read_csv('nba.csv')
print(data)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
data.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
data.shape
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.loc[0:2]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
data_1=pd.read_csv('ipl_21.csv')
data_1
# Out:
#     Match Number        Round Number        Date  \
# 0              1                   1  09-04-2021
# 1              2                   1  10-04-2021
# 2              3                   1  11-04-2021
# 3              4                   1  12-04-2021
# 4              5                   1  13-04-2021
# 5              6                   1  14-04-2021
# 6              7                   1  15-04-2021
# 7              8                   2  16-04-2021
# 8              9                   2  17-04-2021
# 9             10                   2  18-04-2021
# 10            11                   2  18-04-2021
# 11            12                   2  19-04-2021
# 12            13                   2  20-04-2021
# 13            14                   2  21-04-2021
# 14            15                   2  21-04-2021
# 15            16                   2  22-04-2021
# 16            17                   3  23-04-2021
# 17            18                   3  24-04-2021
# ...

# %%
data_1.loc[10:20]
# Out:
#     Match Number Round Number              Date  \
# 10            11            2  18/04/2021 19:30
# 11            12            2  19/04/2021 19:30
# 12            13            2  20/04/2021 19:30
# 13            14            2  21/04/2021 15:30
# 14            15            2  21/04/2021 19:30
# 15            16            2  22/04/2021 19:30
# 16            17            3  23/04/2021 19:30
# 17            18            3  24/04/2021 19:30
# 18            19            3  25/04/2021 15:30
# 19            20            3  25/04/2021 19:30
# 20            21            3  26/04/2021 19:30
#
#                               Location                    Home Team  \
# 10            Wankhede Stadium, Mumbai               Delhi Capitals
# 11            Wankhede Stadium, Mumbai          Chennai Super Kings
# 12  M. A. Chidambaram Stadium, Chennai               Delhi Capitals
# 13  M. A. Chidambaram Stadium, Chennai                 Punjab Kings
# ...

# %%
data_1.iloc[5:11,7:8]
data_1.loc[5:10,("Match Number","Round Number")]
# Out:
#     Match Number Round Number
# 5              6            1
# 6              7            1
# 7              8            2
# 8              9            2
# 9             10            2
# 10            11            2

# %%
data_1
# Out:
#     Match Number        Round Number              Date  \
# 0              1                   1  09/04/2021 19:30
# 1              2                   1  10/04/2021 19:30
# 2              3                   1  11/04/2021 19:30
# 3              4                   1  12/04/2021 19:30
# 4              5                   1  13/04/2021 19:30
# 5              6                   1  14/04/2021 19:30
# 6              7                   1  15/04/2021 19:30
# 7              8                   2  16/04/2021 19:30
# 8              9                   2  17/04/2021 19:30
# 9             10                   2  18/04/2021 15:30
# 10            11                   2  18/04/2021 19:30
# 11            12                   2  19/04/2021 19:30
# 12            13                   2  20/04/2021 19:30
# 13            14                   2  21/04/2021 15:30
# 14            15                   2  21/04/2021 19:30
# 15            16                   2  22/04/2021 19:30
# ...

# %%
data_1.drop([58,59],axis=0)
# Out:
#     Match Number        Round Number              Date  \
# 0              1                   1  09/04/2021 19:30
# 1              2                   1  10/04/2021 19:30
# 2              3                   1  11/04/2021 19:30
# 3              4                   1  12/04/2021 19:30
# 4              5                   1  13/04/2021 19:30
# 5              6                   1  14/04/2021 19:30
# 6              7                   1  15/04/2021 19:30
# 7              8                   2  16/04/2021 19:30
# 8              9                   2  17/04/2021 19:30
# 9             10                   2  18/04/2021 15:30
# 10            11                   2  18/04/2021 19:30
# 11            12                   2  19/04/2021 19:30
# 12            13                   2  20/04/2021 19:30
# 13            14                   2  21/04/2021 15:30
# 14            15                   2  21/04/2021 19:30
# 15            16                   2  22/04/2021 19:30
# ...

# %%
data_2=data_1.head()
data_2=data_2.drop(["Result","Group"],axis=1)
data_2
# Out:
#    Match Number Round Number        Date                            Location  \
# 0             1            1  09-04-2021  M. A. Chidambaram Stadium, Chennai
# 1             2            1  10-04-2021            Wankhede Stadium, Mumbai
# 2             3            1  11-04-2021  M. A. Chidambaram Stadium, Chennai
# 3             4            1  12-04-2021            Wankhede Stadium, Mumbai
# 4             5            1  13-04-2021  M. A. Chidambaram Stadium, Chennai
#
#                Home Team                    Away Team
# 0         Mumbai Indians  Royal Challengers Bangalore
# 1    Chennai Super Kings               Delhi Capitals
# 2    Sunrisers Hyderabad        Kolkata Knight Riders
# 3       Rajasthan Royals                 Punjab Kings
# 4  Kolkata Knight Riders               Mumbai Indians

# %%
def half(s):
    return s*0.5
print(data_2[['Match Number']].apply(half))
# Out:
#    Match Number
# 0           0.5
# 1           1.0
# 2           1.5
# 3           2.0
# 4           2.5

# %%
data_2
# Out:
#    Match Number Round Number        Date                            Location  \
# 0             1            1  09-04-2021  M. A. Chidambaram Stadium, Chennai
# 1             2            1  10-04-2021            Wankhede Stadium, Mumbai
# 2             3            1  11-04-2021  M. A. Chidambaram Stadium, Chennai
# 3             4            1  12-04-2021            Wankhede Stadium, Mumbai
# 4             5            1  13-04-2021  M. A. Chidambaram Stadium, Chennai
#
#                Home Team                    Away Team
# 0         Mumbai Indians  Royal Challengers Bangalore
# 1    Chennai Super Kings               Delhi Capitals
# 2    Sunrisers Hyderabad        Kolkata Knight Riders
# 3       Rajasthan Royals                 Punjab Kings
# 4  Kolkata Knight Riders               Mumbai Indians

# %%
convert={'Round Number':int}
data_2=data_2.astype(convert)
data_2.dtypes
data_2[['Match Number','Round Number']].apply(half)
# Out:
#    Match Number  Round Number
# 0           0.5           0.5
# 1           1.0           0.5
# 2           1.5           0.5
# 3           2.0           0.5
# 4           2.5           0.5

# %%
data_2
def add(s):
    return s+5 
data_2[['Match Number','Round Number']].apply(add) # we can apply user defined function on dataframe
# Out:
#    Match Number  Round Number
# 0             6             6
# 1             7             6
# 2             8             6
# 3             9             6
# 4            10             6
